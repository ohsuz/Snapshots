# %%
cd 원하는드라이브
# Out:
# /content/drive/MyDrive/2021/Dacon

# %%
# !git config --global user.name 유저네임
# !git config --global user.email 유저이메일

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/2021/Dacon/.git/

# %%
# !git add *
# Out:
# The following paths are ignored by one of your .gitignore files:
# data
# logits
# models
# submissions
# Use -f if you really want to add them.

# %%
# !git commit -m '커밋메세지~~!'
# !git branch -M main
# Out:
# [master (root-commit) af11289] [done] baseline - notebook ver
#  2 files changed, 2 insertions(+)
#  create mode 100644 notebooks/Make Baseline.ipynb
#  create mode 100644 notebooks/[practice] Translation.ipynb

# %%
# !git remote add origin https://유저네임:비밀번호@github.com/레파지토리주소

# %%
# !git push -u origin main
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (5/5), 13.54 KiB | 1.93 MiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0)
# To https://github.com/ohsuz/Climate-Technology-Classification-Competition.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
